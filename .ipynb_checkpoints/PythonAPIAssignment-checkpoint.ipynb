# %%
# Import Dependencies 
import pandas as pd
import matplotlib.pyplot as plt
import openweathermapy.core as owm
import random
import numpy as np
import seaborn as sns
import urllib
from urllib.error import HTTPError
from citipy import citipy
from config import api_key
from random import uniform
from datetime import datetime
import time

# Query URL
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid=api_key&units=&q="

# Create output csv file
output_csv = "city_weather.csv"

# %%
# Create lists for latitude and longitude

lat = []
lon = []

# Use random.uniform to generate random latitude and longitude values
for x in range(2000):
    lat.append(random.uniform(-90,90))
    lon.append(random.uniform(-180,180))
    
# Use citipy to define city and country from coordinates
# Create a new df

cities_df = pd.DataFrame({"Latitude": lat, "Longitude": lon, "City":""})

for index,row in cities_df.iterrows():
    city = citipy.nearest_city(row['Latitude'], row['Longitude'])
    cities_df.at[index,"City"] = (f"{city.city_name},{city.country_code}")
    
    
# Drop duplicates if any
cities_df = cities_df.drop_duplicates(["City"], keep='first')
cities_df = cities_df.reset_index(drop=True)

# %%
# Create settings parameters
settings = {"units": "imperial", "appid": api_key}

# Run API calls and collect data
params = ['name','clouds.all','sys.country','dt','main.humidity','main.temp','wind.speed']


for index,row in cities_df.iterrows():
    try:
        city = row['City']
        data = owm.get_current(city, **settings)
        results = data(*params)
        cities_df.at[index,'City'] = (results[0])
        cities_df.at[index,'Cloudiness'] = (int(results[1]))
        cities_df.at[index,'Country'] = (results[2])
        cities_df.at[index,'Date'] = (results[3])
        cities_df.at[index,'Humidity'] = (int(results[4]))
        #cities_df.at[index,'Lng'] = (results[5])
        cities_df.at[index,'Max Temp'] = (results[5])     
        cities_df.at[index,'Wind Speed'] = (results[6])
        print(f"Retrieving Results for Index {index}: {city}.")
        print(f"{url} + {query_url}")
    # Skip the city if an error is encountered
    
         # Wait a second in loop to not over exceed rate limit of API
        counter = 0
        time.sleep(.01)
        counter += 1
        if counter == 500:
            break
            
    except(HTTPError): 
        print(f"Processing Record {index}: {city}")
        print(f"Missing field/result for {row['City']}. Skipping.")
        pass
    
# Print notification when complete
print("----------------------------")
print("Data Retrieval Complete     ")
# Out:
# Retrieving Results for Index 0: lysa hora,ua.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 1: makhinjauri,ge.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 2: santa isabel do rio negro,br.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 3: busselton,au.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 4: kunming,cn.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 5: gimli,ca.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 6: hermanus,za.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 7: rikitea,pf.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 8: marsabit,ke.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 9: keetmanshoop,na.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 10: mataura,pf
# Missing field/result for mataura,pf. Skipping.
# Retrieving Results for Index 11: faanui,pf.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 12: do gonbadan,ir.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 13: bethel,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 14: pevek,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 15: cidreira,br.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 16: alofi,nu.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 17: aswan,eg.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 18: louisbourg,ca
# Missing field/result for louisbourg,ca. Skipping.
# Retrieving Results for Index 19: castro,cl.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 20: saint-philippe,re.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 21: albany,au.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 22: kamenskoye,ru
# Missing field/result for kamenskoye,ru. Skipping.
# Retrieving Results for Index 23: barrow,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 24: esperance,au.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 25: flinders,au.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 26: progreso,mx.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 27: taolanaro,mg
# Missing field/result for taolanaro,mg. Skipping.
# Retrieving Results for Index 28: tuatapere,nz.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 29: tondano,id.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 30: hithadhoo,mv.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 31: butaritari,ki.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 32: bambous virieux,mu.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 33: palabuhanratu,id
# Missing field/result for palabuhanratu,id. Skipping.
# Processing Record 34: vestbygda,no
# Missing field/result for vestbygda,no. Skipping.
# Retrieving Results for Index 35: zheshart,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 36: fairbanks,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 37: nakamura,jp.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 38: kuche,cn
# Missing field/result for kuche,cn. Skipping.
# Retrieving Results for Index 39: lorengau,pg.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 40: kapaa,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 41: kahului,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 42: vila franca do campo,pt.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 43: matagami,ca.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 44: longyearbyen,sj.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 45: broome,au.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 46: mandali,iq.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 47: kuching,my.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 48: yorkton,ca.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 49: cherskiy,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 50: norman wells,ca.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 51: ushuaia,ar.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 52: georgetown,sh.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 53: nizhneyansk,ru
# Missing field/result for nizhneyansk,ru. Skipping.
# Retrieving Results for Index 54: provideniya,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 55: puerto ayora,ec.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 56: lagoa,pt.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 57: punta arenas,cl.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 58: sentyabrskiy,ru
# Missing field/result for sentyabrskiy,ru. Skipping.
# Retrieving Results for Index 59: belaya gora,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 60: atuona,pf.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 61: illoqqortoormiut,gl
# Missing field/result for illoqqortoormiut,gl. Skipping.
# Processing Record 62: barentsburg,sj
# Missing field/result for barentsburg,sj. Skipping.
# Processing Record 63: bara,sd
# Missing field/result for bara,sd. Skipping.
# Processing Record 64: faya,td
# Missing field/result for faya,td. Skipping.
# Retrieving Results for Index 65: mehamn,no.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 66: qasigiannguit,gl.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 67: hilo,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 68: nikolskoye,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 69: jamestown,sh.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 70: salinopolis,br.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 71: kuopio,fi.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 72: biak,id.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 73: namibe,ao.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 74: hobart,au.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 75: bilma,ne.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 76: ponta do sol,cv.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 77: durham,ca.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 78: boffa,gn.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 79: geraldton,au.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 80: leningradskiy,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 81: san cristobal,ec.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 82: cape town,za.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 83: cayenne,gf.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 84: cerro de pasco,pe.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 85: carnarvon,au.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 86: vaitupu,wf
# Missing field/result for vaitupu,wf. Skipping.
# Retrieving Results for Index 87: henties bay,na.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 88: arraial do cabo,br.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 89: port elizabeth,za.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 90: thompson,ca.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 91: sofiysk,ru
# Missing field/result for sofiysk,ru. Skipping.
# Retrieving Results for Index 92: tabory,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 93: nabire,id.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 94: cabo san lucas,mx.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 95: khatanga,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 96: yelovo,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 97: boende,cd.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 98: bluff,nz.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 99: potenza,it.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 100: hvide sande,dk.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 101: tabarqah,tn
# Missing field/result for tabarqah,tn. Skipping.
# Retrieving Results for Index 102: chuy,uy.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 103: kenora,ca.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 104: saint george,bm.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 105: smithers,ca.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 106: lamar,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 107: yulara,au.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 108: lodwar,ke.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 109: kaitangata,nz.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 110: port alfred,za.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 111: leua,ao.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 112: chokurdakh,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 113: andenes,no.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 114: college,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 115: upernavik,gl.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 116: bredasdorp,za.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 117: bend,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 118: birao,cf.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 119: japoata,br.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 120: chivacoa,ve.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 121: avarua,ck.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 122: attawapiskat,ca
# Missing field/result for attawapiskat,ca. Skipping.
# Retrieving Results for Index 123: alta,no.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 124: montauban,fr.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 125: mukhen,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 126: kulti,in.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 127: tsihombe,mg
# Missing field/result for tsihombe,mg. Skipping.
# Retrieving Results for Index 128: pak phanang,th.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 129: haljala,ee.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 130: vestmanna,fo.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 131: kodiak,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 132: lompoc,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 133: victoria,sc.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 134: ansalta,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 135: baherden,tm.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 136: lebu,cl.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 137: west memphis,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 138: vysokogornyy,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 139: camacha,pt.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 140: sitka,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 141: vardo,no.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 142: kasamwa,tz.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 143: tukan,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 144: dubbo,au.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 145: souillac,mu.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 146: kavaratti,in.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 147: keizer,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 148: phan rang,vn
# Missing field/result for phan rang,vn. Skipping.
# Retrieving Results for Index 149: oxford,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 150: pacific grove,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 151: xuddur,so.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 152: narsaq,gl.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 153: tuktoyaktuk,ca.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 154: staryy nadym,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 155: quetigny,fr.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 156: omsukchan,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 157: hualmay,pe.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 158: bagan,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 159: tumannyy,ru
# Missing field/result for tumannyy,ru. Skipping.
# Retrieving Results for Index 160: san luis,ar.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 161: yellowknife,ca.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 162: comodoro rivadavia,ar.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 163: vaini,to.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 164: nha trang,vn.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 165: asau,tv
# Missing field/result for asau,tv. Skipping.
# Processing Record 166: acatlan,mx
# Missing field/result for acatlan,mx. Skipping.
# Retrieving Results for Index 167: puerto baquerizo moreno,ec.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 168: juneau,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 169: grand river south east,mu
# Missing field/result for grand river south east,mu. Skipping.
# Processing Record 170: dhola,in
# Missing field/result for dhola,in. Skipping.
# Retrieving Results for Index 171: hazorasp,uz.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 172: roskovec,al.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 173: kununurra,au.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 174: satana,in.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 175: sao filipe,cv.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 176: gualaquiza,ec.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 177: macas,ec.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 178: qaanaaq,gl.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 179: plattsburgh,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 180: tazovskiy,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 181: severo-kurilsk,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 182: jacareacanga,br.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 183: cabimas,ve.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 184: zhicheng,cn.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 185: naze,jp.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 186: uglegorsk,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 187: portland,au.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 188: snyder,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 189: sechura,pe.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 190: songkhla,th.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 191: bengkulu,id
# Missing field/result for bengkulu,id. Skipping.
# Retrieving Results for Index 192: east london,za.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 193: plouzane,fr.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 194: pemangkat,id
# Missing field/result for pemangkat,id. Skipping.
# Retrieving Results for Index 195: rye,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 196: gbarnga,lr.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 197: paita,pe.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 198: aksu,cn.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 199: alice springs,au.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 200: camana,pe
# Missing field/result for camana,pe. Skipping.
# Retrieving Results for Index 201: borisoglebsk,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 202: san policarpo,ph.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 203: margate,za.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 204: mar del plata,ar.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 205: bilibino,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 206: zeya,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 207: meyungs,pw
# Missing field/result for meyungs,pw. Skipping.
# Retrieving Results for Index 208: ribeira grande,pt.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 209: tiksi,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 210: maloshuyka,ru
# Missing field/result for maloshuyka,ru. Skipping.
# Retrieving Results for Index 211: torbay,ca.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 212: marzuq,ly
# Missing field/result for marzuq,ly. Skipping.
# Retrieving Results for Index 213: mount gambier,au.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 214: mulchen,cl.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 215: taoudenni,ml.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 216: latehar,in.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 217: pontian kecil,my.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 218: leh,in.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 219: new norfolk,au.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 220: kushima,jp.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 221: nanortalik,gl.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 222: praya,id.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 223: vila velha,br.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 224: wuwei,cn.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 225: alotau,pg
# Missing field/result for alotau,pg. Skipping.
# Retrieving Results for Index 226: madimba,tz.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 227: vizinga,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 228: vostok,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 229: saint-denis,re.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 230: paucartambo,pe
# Missing field/result for paucartambo,pe. Skipping.
# Retrieving Results for Index 231: lucapa,ao.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 232: charters towers,au.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 233: pisco,pe.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 234: sobolevo,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 235: dakar,sn.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 236: geraldton,ca.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 237: honningsvag,no.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 238: sopot,pl.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 239: iqaluit,ca.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 240: bardiyah,ly.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 241: terrace,ca.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 242: iquique,cl.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 243: barranca,pe.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 244: amderma,ru
# Missing field/result for amderma,ru. Skipping.
# Retrieving Results for Index 245: hasaki,jp.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 246: saleaula,ws
# Missing field/result for saleaula,ws. Skipping.
# Retrieving Results for Index 247: makakilo city,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 248: safford,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Processing Record 249: kalomo,zm
# Missing field/result for kalomo,zm. Skipping.
# Retrieving Results for Index 250: port macquarie,au.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 251: champerico,gt.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 252: miraflores,co.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 253: dese,et.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 254: ancud,cl.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 255: vao,nc.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 256: isangel,vu.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 257: komsomolskiy,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 258: tual,id.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 259: ca mau,vn.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 260: palmer,us.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 261: luderitz,na.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 262: carnarvon,za.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 263: sao joao da barra,br.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 264: lavrentiya,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# Retrieving Results for Index 265: ust-nera,ru.
# http://api.openweathermap.org/data/2.5/weather? + http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=&q=
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# <ipython-input-3-af6a763c39ea> in <module>
#       9     try:
#      10         city = row['City']
# ---> 11         data = owm.get_current(city, **settings)
#      12         results = data(*params)
#      13         cities_df.at[index,'City'] = (results[0])
#
# ~/anaconda3/lib/python3.7/site-packages/openweathermapy/core.py in get_current(city, **params)
#     153            >>> data = get_current(zip="34128,DE")
#     154 	"""
# --> 155         data = wrap_get("weather")(city, **params)
#     156         return DataPoint(data)
#     157
#
# ~/anaconda3/lib/python3.7/site-packages/openweathermapy/core.py in call(loc, **params)
#      97                 if settings:
#      98                         params.update(settings)
# ---> 99                 data = get(url, **params)
#     100                 if converter:
#     101                         data = converter(data)
#
# ~/anaconda3/lib/python3.7/site-packages/openweathermapy/core.py in get(url, **params)
#      60 def get(url, **params):
#      61         """Return data as (nested) dictionary for ``url`` request."""
# ---> 62         data = utils.get_url_response(url, **params)
#      63         # Decoding: Python3 compatibility
#      64         return json.loads(data.decode("utf-8"))
#
# ~/anaconda3/lib/python3.7/site-packages/openweathermapy/utils.py in get_url_response(url, **params)
#      29         if params:
#      30                 url = url+"?"+urlencode(params)
# ---> 31         response = urlopen(url)
#      32         data = response.read()
#      33         response.close()
#
# ~/anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in http_open(self, req)
#    1343
#    1344     def http_open(self, req):
# -> 1345         return self.do_open(http.client.HTTPConnection, req)
#    1346
#    1347     http_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
# -> 1320             r = h.getresponse()
#    1321         except:
#    1322             h.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ConnectionResetError: [Errno 54] Connection reset by peer

# %%
# Drop the nulls and count the number of cities with data retrieved
cities_df = cities_df.dropna(how='any')
cities_df.count()
# Out:
# Latitude      231
# Longitude     231
# City          231
# Cloudiness    231
# Country       231
# Date          231
# Humidity      231
# Max Temp      231
# Wind Speed    231
# dtype: int64

# %%
# Display the city dataframe
cities_df.head()
# Out:
#     Latitude   Longitude                       City  Cloudiness Country  \
# 0  48.052688   31.131445                  Lysa Hora        15.0      UA
# 1  41.768515   41.575851                Makhinjauri        75.0      GE
# 2  -0.178319  -65.515020  Santa Isabel do Rio Negro        51.0      BR
# 3 -63.038398   91.821561                  Busselton         0.0      AU
# 4  26.122312  102.775335                    Kunming        75.0      CN
#
#            Date  Humidity  Max Temp  Wind Speed
# 0  1.563026e+09      57.0     67.78        4.21
# 1  1.563026e+09      69.0     75.20        5.82
# 2  1.563026e+09      75.0     82.72        4.52
# 3  1.563025e+09      59.0     45.32       16.60
# 4  1.563026e+09      93.0     62.60        8.95

# %%
# Output results to csv file
cities_df.to_csv(output_csv)

# %%
#Get today's date
date = datetime.now()
today = date.strftime("%m/%d/%y")

# Build a scatter plot to show the relationship between Temperature (F) vs Latitude
sns.set_style('darkgrid')
sns.set(font_scale=1.25)
sns.lmplot(x='Latitude', y='Max Temp', data=cities_df, fit_reg=False, size = 8, scatter_kws={'alpha':1, 'linewidths':1, 'edgecolor':'k'})

plt.title(f"City Latitude vs. Max Temperature ({today})")
plt.ylabel("Max Temperature (F)")
# Save as png file
plt.savefig("lat_temp.png")
# Show plot
plt.show()
# Out:
# /Users/kiranbabukalluri/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Build a scatter plot to show the relationship between Humidity vs Latitude
sns.set_style('darkgrid')
sns.set(font_scale=1.25)
sns.lmplot(x='Latitude', y='Humidity', data=cities_df, fit_reg=False, size = 8, scatter_kws={'alpha':1, 'linewidths':1, 'edgecolor':'k'})

plt.title(f"City Latitude vs. Humidity ({today})")

# Save as png file
plt.savefig("lat_humidity.png")
# Show plot
plt.show()
# Out:
# /Users/kiranbabukalluri/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Build a scatter plot to show the relationship between Cloudiness vs Latitude
sns.set_style('darkgrid')
sns.set(font_scale=1.25)
sns.lmplot(x='Latitude', y='Cloudiness', data=cities_df, fit_reg=False, size = 8, scatter_kws={'alpha':1, 'linewidths':1, 'edgecolor':'k'})

plt.title(f"City Latitude vs. Cloudiness ({today})")
plt.ylabel("Cloudiness (%)")

# Save as png file
plt.savefig("lat_cloudiness.png")
# Show plot
plt.show()
# Out:
# /Users/kiranbabukalluri/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Build a scatter plot to show the relationship between Wind Speed vs Latitude
sns.set_style('darkgrid')
sns.set(font_scale=1.25)
sns.lmplot(x='Latitude', y='Wind Speed', data=cities_df, fit_reg=False, size = 8, scatter_kws={'alpha':1, 'linewidths':1, 'edgecolor':'k'})

plt.title(f"City Latitude vs. Wind Speed ({today})")
plt.ylabel("Wind Speed (mph)")

# Save as png file
plt.savefig("lat_wind.png")
# Show plot
plt.show()
# Out:
# /Users/kiranbabukalluri/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
